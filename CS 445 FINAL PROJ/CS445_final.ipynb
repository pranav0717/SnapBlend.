# %%
print("fuck this s|hhhhitiii000000000")
# Out:
# fuck this s|hhhhitiii000000000

# %%
import cv2

import numpy as np
import scipy as sc
from matplotlib.colors import LogNorm
from scipy import signal

# modify to where you store your project data including utils.py
datadir = "/Users/pranav/Desktop/CS445/fianl_proj/" 


utilfn = datadir + "utils.py"
# !cp "$utilfn" .
samplesfn = datadir + "samples"
# !cp -r "$samplesfn" .
import utils
# Out:
# cp: ./utils.py and /Users/pranav/Desktop/CS445/fianl_proj/utils.py are identical (not copied).
# cp: ./samples and /Users/pranav/Desktop/CS445/fianl_proj/samples are identical (not copied).

# %%
# switch from notebook to inline if using colab or otherwise cannot use interactive display)
# %matplotlib notebook  
import matplotlib.pyplot as plt

# %% [markdown]
# Shades Filter

# %%
# File paths
shades_file = 'samples/shades.png'
face_file = 'samples/nazar_face.jpeg'



im1 = cv2.imread(shades_file, cv2.IMREAD_COLOR)
im2 = cv2.imread(face_file, cv2.IMREAD_COLOR)


plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(im1, cv2.COLOR_BGR2RGB))
plt.title('Shades Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.title('Face Image')
plt.axis('off')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
